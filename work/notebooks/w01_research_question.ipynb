# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/kratosontren/flyrank-ml-work/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# ## Lane: Refresh / Content Opportunity Scoring
#
# I chose the Refresh / Content Opportunity Scoring lane because large websites often contain thousands of pages, making manual review difficult and expensive. A system that identifies pages likely to decline could help teams prioritize which pages should be refreshed first.
#
# The starter notebooks already demonstrated that machine learning substantially outperformed a simple hand-written rule for identifying declining pages. This suggests that page decline may depend on multiple interacting signals rather than a single metric, making it a suitable problem for further analysis over the next seven weeks.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# ## Research Question
#
# Which pages should be reviewed first for content refresh?
#
# ### Unit of Analysis
# Individual webpage/content page.
#
# ### Decision
# Which pages should be prioritized for refresh or review?
#
# ### Action
# SEO teams can prioritize:
#
# - content updates
# - rewrites
# - audits
# - monitoring
#
# for pages predicted to be at risk.
#
# ### Cost of Wrong Recommendations
#
# False Positives:
# Refreshing pages that did not require intervention, resulting in wasted resources and analyst time.
#
# False Negatives:
# Failing to refresh pages that continue to lose traffic and rankings, potentially causing business losses and missed opportunities.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# ## Why this lane appears promising
#
# The starter dataset already provides evidence that this problem may benefit from machine learning approaches.
#
# The dataset contains approximately 30,000 pages and 44 variables.
#
# The starter notebooks also showed that machine learning substantially improved Precision@50 compared with a hand-written rule.
#
# Additionally, search volume and actual impressions appear to have almost no linear relationship, suggesting that page decline is likely influenced by multiple interacting factors.

# %%
# !ls flyrank-ml-work/data/raw/
# Out:
# content_refresh_anonymized.csv

# %%
import pandas as pd
import json

df = pd.read_csv(
    "/content/flyrank-ml-work/data/raw/content_refresh_anonymized.csv"
)

print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

corr = df["search_volume"].corr(
    df["impressions_90d"]
)

print(
    "\nCorrelation between search volume and impressions:",
    round(corr,3)
)
# Out:
# Rows: 30000
# Columns: 44
#
# Correlation between search volume and impressions: 0.001

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# ## What this project can claim
#
# This project aims to identify observed patterns and directional relationships that may help prioritize content refresh decisions.
#
# The results may provide decision-support insights regarding which pages appear more likely to decline and therefore deserve review.
#
# The project may also show whether machine learning approaches can improve prioritization compared with simple rule-based methods on the available dataset.
#
# ## What this project cannot claim
#
# This project cannot prove causal relationships between content features and search performance.
#
# It cannot explain or predict Google's ranking algorithm, guarantee that refreshing a page will improve rankings, or prove that a specific action caused future traffic changes.
#
# Any findings should therefore be interpreted as observational, predictive, and decision-support evidence rather than causal proof.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
